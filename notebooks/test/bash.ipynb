# %% [markdown]
# # Bash Kernel Test Notebook
# Validation and basic shell demos for the Bash kernel.

# %%
echo "Kernel sanity check"
echo "Shell: $SHELL"
uname -a

# %%
echo "Key binaries"
command -v bash
command -v python || true
command -v spack || true

# %%
echo "Workspace quick view"
pwd
ls -lah | head -n 20
