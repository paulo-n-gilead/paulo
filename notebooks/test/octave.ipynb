# %% [markdown]
# # Octave Kernel Test Notebook
# Validation and numerical demos for the Octave kernel.

# %%
version
disp("Octave kernel basic check OK")

# %%
A = [1 2; 3 4];
disp("Matrix A:");
disp(A);
disp("det(A)=");
disp(det(A));

# %%
x = linspace(0, 2*pi, 200);
y = cos(x);
plot(x, y, 'r-', 'linewidth', 2);
title('Cosine Wave Demo');
xlabel('x'); ylabel('cos(x)'); grid on;
