# %% [markdown]
# # R Kernel Test Notebook
# Quick validation and demo for the IRkernel setup.

# %%
sessionInfo()

# %%
cat("R version: ", R.version.string, "\n")
cat("IRkernel loaded:\n")
library(IRkernel)
cat("OK\n")

# %%
x <- seq(0, 2*pi, length.out = 100)
y <- sin(x)
plot(x, y, type = 'l', col = 'steelblue', lwd = 2, main = 'Sine Wave Demo', xlab = 'x', ylab = 'sin(x)')
